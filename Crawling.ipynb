# %%
import twint

c = twint.Config()
c.Search = "#shopeepaylater"
#c.Since = "2018-08-01"
#c.Until = "2022-01-29"
#c.Year = 2021
c.Limit = 500
c.Pandas = True

twint.run.Search(c)

def column_names():
    return twint.output.panda.Tweets_df.columns

def twint_to_pd(columns):
    return twint.output.panda.Tweets_df[columns]

print(column_names())

# ['id', 'conversation_id', 'created_at', 'date', 'timezone', 'place',
#        'tweet', 'language', 'hashtags', 'cashtags', 'user_id', 'user_id_str',
#        'username', 'name', 'day', 'hour', 'link', 'urls', 'photos', 'video',
#        'thumbnail', 'retweet', 'nlikes', 'nreplies', 'nretweets', 'quote_url',
#        'search', 'near', 'geo', 'source', 'user_rt_id', 'user_rt',
#        'retweet_id', 'reply_to', 'retweet_date', 'translate', 'trans_src',
#        'trans_dest']

data = twint_to_pd(['date', 'username', 'tweet'])
#data = twint_to_pd
print(data)

data.to_csv('scraping_shopeepaylater_twitter.csv', index=False)

# %%
import twint

c = twint.Config()
c.Search = "#ovopaylater"
#c.Since = "2018-08-01"
#c.Until = "2022-01-29"
#c.Year = 2021
c.Limit = 500
c.Pandas = True

twint.run.Search(c)

def column_names():
    return twint.output.panda.Tweets_df.columns

def twint_to_pd(columns):
    return twint.output.panda.Tweets_df[columns]

print(column_names())

# ['id', 'conversation_id', 'created_at', 'date', 'timezone', 'place',
#        'tweet', 'language', 'hashtags', 'cashtags', 'user_id', 'user_id_str',
#        'username', 'name', 'day', 'hour', 'link', 'urls', 'photos', 'video',
#        'thumbnail', 'retweet', 'nlikes', 'nreplies', 'nretweets', 'quote_url',
#        'search', 'near', 'geo', 'source', 'user_rt_id', 'user_rt',
#        'retweet_id', 'reply_to', 'retweet_date', 'translate', 'trans_src',
#        'trans_dest']

data = twint_to_pd(['date', 'username', 'tweet'])
#data = twint_to_pd
print(data)

data.to_csv('scraping_ovopaylater_twitter.csv', index=False)

# %%
import twint

c = twint.Config()
c.Search = "#gopaylater"
#c.Since = "2018-08-01"
#c.Until = "2022-01-29"
#c.Year = 2021
c.Limit = 500
c.Pandas = True

twint.run.Search(c)

def column_names():
    return twint.output.panda.Tweets_df.columns

def twint_to_pd(columns):
    return twint.output.panda.Tweets_df[columns]

print(column_names())

# ['id', 'conversation_id', 'created_at', 'date', 'timezone', 'place',
#        'tweet', 'language', 'hashtags', 'cashtags', 'user_id', 'user_id_str',
#        'username', 'name', 'day', 'hour', 'link', 'urls', 'photos', 'video',
#        'thumbnail', 'retweet', 'nlikes', 'nreplies', 'nretweets', 'quote_url',
#        'search', 'near', 'geo', 'source', 'user_rt_id', 'user_rt',
#        'retweet_id', 'reply_to', 'retweet_date', 'translate', 'trans_src',
#        'trans_dest']

data = twint_to_pd(['date', 'username', 'tweet'])
#data = twint_to_pd
print(data)

data.to_csv('scraping_gopaylater_twitter.csv', index=False)
